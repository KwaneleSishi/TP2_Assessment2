# %%
''' 	SR2 – Pre-processing (15 marks):
Write Python code to understand and clean the dataset. This should include:
o	Understanding the size, data types, columns, rows, data slicing and indexing of the dataset as whole.
o	identify missing data 
o	 Normalizing or standardizing data if required
o	Describe the data types that are used in relation to machine learning by using one column for your data set for each machine learning or statistical dataset on a markdown cell.
'''

import pandas as pd 
df = pd.read_csv('C:\\Users\\HP\\Documents\\TPtest\\Informal-Settlement-Matrix.csv')

# %%
#Basic Data Inspection
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 434 entries, 0 to 433
# Data columns (total 22 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   is_cluster               434 non-null    object
#  1   pocket_name              434 non-null    object
#  2   pocket_alias             192 non-null    object
#  3   ward_id                  434 non-null    int64
#  4   ward_councillor          434 non-null    object
#  5   avg_hhsize               434 non-null    float64
#  6   area_ha                  434 non-null    float64
#  7   density_dwellings        434 non-null    float64
#  8   structure_count          434 non-null    int64
#  9   age_of_is                434 non-null    object
#  10  upgrade_category         434 non-null    object
#  11  temp_sanitation          434 non-null    float64
#  12  toilets_full_flush       434 non-null    float64
#  13  toilets_chemical         434 non-null    float64
# ...

# %%
#Identify missing data
missing_values = df.isnull().sum() 
print(missing_values)
# Out:
# is_cluster                   0
# pocket_name                  0
# pocket_alias               242
# ward_id                      0
# ward_councillor              0
# avg_hhsize                   0
# area_ha                      0
# density_dwellings            0
# structure_count              0
# age_of_is                    0
# upgrade_category             0
# temp_sanitation              0
# toilets_full_flush           0
# toilets_chemical             0
# toilets_portable             0
# toilets_container            0
# toilets_other                0
# toilets_total                0
# ratio_toilets_dwellings     91
# pocket_code                  0
# centroidx                    0
# centroidy                    0
# dtype: int64

# %%
#column labels of a dataframe.
df.columns
# Out:
# Index(['is_cluster', 'pocket_name', 'pocket_alias', 'ward_id',
#        'ward_councillor', 'avg_hhsize', 'area_ha', 'density_dwellings',
#        'structure_count', 'age_of_is', 'upgrade_category', 'temp_sanitation',
#        'toilets_full_flush', 'toilets_chemical', 'toilets_portable',
#        'toilets_container', 'toilets_other', 'toilets_total',
#        'ratio_toilets_dwellings', 'pocket_code', 'centroidx', 'centroidy'],
#       dtype='object')

# %%
#Data Types
df.dtypes
# Out:
# is_cluster                  object
# pocket_name                 object
# pocket_alias                object
# ward_id                      int64
# ward_councillor             object
# avg_hhsize                 float64
# area_ha                    float64
# density_dwellings          float64
# structure_count              int64
# age_of_is                   object
# upgrade_category            object
# temp_sanitation            float64
# toilets_full_flush         float64
# toilets_chemical           float64
# toilets_portable           float64
# toilets_container          float64
# toilets_other              float64
# toilets_total              float64
# ratio_toilets_dwellings     object
# pocket_code                 object
# centroidx                  float64
# centroidy                  float64
# dtype: object

# %%
#the size in the DataFrame
df.size
# Out:
# 9548

# %%
#Shape
df.shape
# Out:
# (434, 22)
